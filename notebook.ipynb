# %%
from analyzer import analyze_text

# %%
analyze_text("data/sample.txt")
# Out:
# 📊 Text Analysis Results:
#
# Total Words: 23
# Total Sentences: 3
# Total Characters: 146
#
# 🔥 Most Common Words:
# language: 2
# nlp: 2
# is: 2
# natural: 1
# processing: 1
